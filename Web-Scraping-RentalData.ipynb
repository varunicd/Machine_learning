# %% [markdown]
# # Building Rental Property Dataset Using Web Scraping

# %% [markdown]
# #### Team Members:<br>
# Madhu Bandru - MB4236<br>
# Varun Kumar B - VB475<br>
# Karthikreddy Kuna - KK3375<br>
# Pradeep Kumar Kankipati - PK593

# %%
#importing required libraries
import requests, re, pandas
from bs4 import BeautifulSoup
from collections import defaultdict

# %%
#extracting top market cities and their states

base_url = "https://www.apartments.com/"
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}
response = requests.get(base_url, headers=headers)
soup1 = BeautifulSoup(response.text,"html.parser")

city_url = soup1.find_all("div",{"class":"clearfix"})
list_city=[]
for i in city_url:
     data=i.find_all("li")
for j in data:
    if re.search(r'Pet',j.find("a")["title"]):
        break
    else:
        list_city.append(j.find("a")["href"])
list_city
# Out:
# ['/atlanta-ga/',
#  '/austin-tx/',
#  '/baltimore-md/',
#  '/boston-ma/',
#  '/chicago-il/',
#  '/cincinnati-oh/',
#  '/dallas-tx/',
#  '/denver-co/',
#  '/detroit-mi/',
#  '/houston-tx/',
#  '/irvine-ca/',
#  '/los-angeles-ca/',
#  '/miami-fl/',
#  '/nashville-tn/',
#  '/nj/',
#  '/new-york-ny/',
#  '/orlando-fl/',
#  '/philadelphia-pa/',
#  '/phoenix-az/',
#  '/portland-or/',
#  '/queens-ny/',
#  '/san-antonio-tx/',
#  '/san-diego-ca/',
#  '/san-francisco-ca/',
#  '/seattle-wa/',
#  '/tampa-fl/',
#  '/washington-dc/']

# %%
#extracting individual property URL's for a city


def get_url_list(each_city):
    url = "https://www.apartments.com"+each_city
    headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}
    response = requests.get(url, headers=headers)
    c=response.text
    soup = BeautifulSoup(c,"html.parser")


    ####get the last page number
    num_list = ''
    page_num = soup.find_all("nav", {"class":"paging"})

    for tags in page_num:
        if tags.find('a'):
            num_list += ((tags.text).strip())
    page_num_list = num_list.replace("\n","").replace(".","")

    last_page_num = page_num_list.split(' ')[len(page_num_list.split(' ')) - 1]

    if last_page_num != '5Next':
        last_page = int(last_page_num)
    else:
        page_num = soup.find_all('p', {'class' : "searchResults"})
        for tags in page_num:
            if tags.find('span'):
                last_page = int(((tags.text).split(' '))[len((tags.text).split(' ')) - 1])

    ####get urls of all properties in all pages
    url_list = []
    current_page = 1
    while current_page < (last_page + 1):

        if current_page == 1:
            url = "https://www.apartments.com"+each_city
            headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}
            response = requests.get(url, headers=headers)
            c=response.text
            soup = BeautifulSoup(c,"html.parser")
        else:
            url = "https://www.apartments.com"+each_city+str(current_page)+"/"
            headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}
            response = requests.get(url, headers=headers)
            c=response.text
            soup = BeautifulSoup(c,"html.parser")

        #appending property URL's to a list.
        placard_header = soup.find_all("li")
        for data in placard_header:
            if data.find('article'):
                data1 = data.find('article')
                url_link = data1.get('data-url')
                if url_link == None:
                    data1 = data.find('a')
                    url_link = data1.get('href')
                    url_list.append(url_link) 
                else:
                    url_list.append(url_link)    
        current_page += 1        
    return url_list

# %%
#Provide the city and state(abbrevation) in city_state field.

city_state = '/philadelphia-pa/'
if city_state not in list_city:
    print('Invalid city or state')
else:
    property_url_list = get_url_list(city_state)

property_url_list[:10]
# Out:
# ['https://www.apartments.com/chestnut-hill-village-philadelphia-pa/4sbjxeh/',
#  'https://www.apartments.com/hanover-north-broad-philadelphia-pa/540bw8m/',
#  'https://www.apartments.com/fallsview-gardens-philadelphia-pa/xk810sq/',
#  'https://www.apartments.com/the-irvine-philadelphia-pa/61hve9v/',
#  'https://www.apartments.com/brookview-apartments-at-elkins-park-elkins-park-pa/ked8x69/',
#  'https://www.apartments.com/lynnewood-gardens-elkins-park-pa/7bjgd3y/',
#  'https://www.apartments.com/colonial-point-apartments-feasterville-trevose-pa/sd0qgc7/',
#  'https://www.apartments.com/henry-on-the-park-apartment-homes-philadelphia-pa/8fjme23/',
#  'https://www.apartments.com/1200-washington-philadelphia-pa/3r6jt4d/',
#  'https://www.apartments.com/the-girard-philadelphia-pa/xhslt9m/']

# %%
#extracting required fields to build the data set for each property in the above list.

property_details = defaultdict(dict)
i = 0
address_var_list = []
for new_url in property_url_list:
    i += 1

    new_response = requests.get(new_url, headers=headers)
    new_c=new_response.text
    new_soup = BeautifulSoup(new_c,"html.parser")

    #####Locate and store Property name in dictionary
    property_name = (new_soup.find("h1", {"class":"propertyName"}).text).strip()
    property_details[i]['property name'] = property_name

    #####Locate and store Property adress in dictionary
    data1 = ''
    property_address = new_soup.find_all("h2")
    for tags in property_address:
        if tags.find('span'):
            data1 += ((tags.text).strip())
    data2 = (data1.replace("\r","").replace("  ","").replace(",","")).split('\n')

    ####few properties have street name as property name.
    if len(data2) == 4:
        property_details[i]['property street'] = data2[0]
        property_details[i]['property city'] = data2[1]
        property_details[i]['property state'] = data2[2]
        property_details[i]['property zipcode'] = data2[3]
    else:
        property_details[i]['property street'] = property_name
        property_details[i]['property city'] = data2[0]
        property_details[i]['property state'] = data2[1]
        property_details[i]['property zipcode'] = data2[2]        

    #####Locate and store Property features in dictionary
    feature_data = ''
    property_features = new_soup.find_all("div", {"class":"rentRollupContainer"})
    for tags in property_features:
        if tags.find('span'):
            feature_data += (tags.text).strip()

    feature_data1 = (feature_data.replace("\t","").replace("\n","")).split("\r")
    property_details[i]['Studio'] = 'NA'
    property_details[i]['1 Bedroom'] = 'NA'
    property_details[i]['2 Bedrooms'] = 'NA'
    property_details[i]['3 Bedrooms'] = 'NA'
    for tags in range(0, len(feature_data1), 3):
        if feature_data1[tags] == 'StudioStudio':
            property_details[i]['Studio'] = feature_data1[tags+2].strip()
        elif feature_data1[tags] == '1 Bedroom1 Bed':
            property_details[i]['1 Bedroom'] = (feature_data1[tags+2]).strip()
        elif feature_data1[tags] == '2 Bedrooms2 Beds':
            property_details[i]['2 Bedrooms'] = feature_data1[tags+2].strip()
        elif feature_data1[tags] == '3 Bedrooms3 Beds':
            property_details[i]['3 Bedrooms'] = feature_data1[tags+2].strip()

    ####Latitude and Longitude of property.
    latitude,longitude = new_soup.find_all("meta", property={"place:location:latitude","place:location:longitude"})
    property_details[i]['Latitude'] = latitude["content"]
    property_details[i]['Longitude'] = longitude["content"]    
    
    #####Append URL 
    property_details[i]['URL'] = new_url

property_details
# Out:
# defaultdict(dict,
#             {1: {'property name': 'Chestnut Hill Village',
#               'property street': '7715 Crittenden St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19118',
#               'Studio': 'NA',
#               '1 Bedroom': '$1,227 – 1,699',
#               '2 Bedrooms': '$1,629 – 2,368',
#               '3 Bedrooms': '$2,039 – 2,054',
#               'Latitude': '40.07447',
#               'Longitude': '-75.19484',
#               'URL': 'https://www.apartments.com/chestnut-hill-village-philadelphia-pa/4sbjxeh/'},
#              2: {'property name': 'Hanover North Broad',
#               'property street': '322-344 N Broad St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19102',
#               'Studio': '$1,582 – 2,005',
#               '1 Bedroom': '$1,701 – 2,742',
#               '2 Bedrooms': '$2,360 – 3,952',
#               '3 Bedrooms': '$3,781 – 3,816',
#               'Latitude': '39.95934',
#               'Longitude': '-75.16261',
#               'URL': 'https://www.apartments.com/hanover-north-broad-philadelphia-pa/540bw8m/'},
#              3: {'property name': 'Fallsview Gardens',
#               'property street': '3026 W Queen Ln',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19129',
#               'Studio': 'NA',
#               '1 Bedroom': 'NA',
#               '2 Bedrooms': '$1,250 – 1,550',
#               '3 Bedrooms': 'NA',
#               'Latitude': '40.01916',
#               'Longitude': '-75.18168',
#               'URL': 'https://www.apartments.com/fallsview-gardens-philadelphia-pa/xk810sq/'},
#              4: {'property name': 'The Irvine',
#               'property street': '780 S 52nd St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19143',
#               'Studio': '$1,295 – 1,645',
#               '1 Bedroom': '$1,575 – 1,795',
#               '2 Bedrooms': '$2,095 – 2,345',
#               '3 Bedrooms': '$2,565 – 2,645',
#               'Latitude': '39.94624',
#               'Longitude': '-75.22589',
#               'URL': 'https://www.apartments.com/the-irvine-philadelphia-pa/61hve9v/'},
#              5: {'property name': 'Brookview Apartments at Elkins Park',
#               'property street': '1235 Ashbourne Rd',
#               'property city': 'Elkins Park',
#               'property state': 'PA',
#               'property zipcode': '19027',
#               'Studio': 'NA',
#               '1 Bedroom': '$1,215 – 1,525',
#               '2 Bedrooms': '$1,600 – 1,765',
#               '3 Bedrooms': '$1,940 – 2,095',
#               'Latitude': '40.06646',
#               'Longitude': '-75.11785',
#               'URL': 'https://www.apartments.com/brookview-apartments-at-elkins-park-elkins-park-pa/ked8x69/'},
#              6: {'property name': 'Lynnewood Gardens',
#               'property street': '1950 Ashbourne Rd',
#               'property city': 'Elkins Park',
#               'property state': 'PA',
#               'property zipcode': '19027',
#               'Studio': 'NA',
#               '1 Bedroom': '$995 – 1,340',
#               '2 Bedrooms': '$1,320 – 1,570',
#               '3 Bedrooms': '$1,800 – 1,975',
#               'Latitude': '40.07215',
#               'Longitude': '-75.14885',
#               'URL': 'https://www.apartments.com/lynnewood-gardens-elkins-park-pa/7bjgd3y/'},
#              7: {'property name': 'Colonial Point Apartments',
#               'property street': '2555 Old Trevose Rd',
#               'property city': 'Feasterville Trevose',
#               'property state': 'PA',
#               'property zipcode': '19053',
#               'Studio': '$920 – 1,250',
#               '1 Bedroom': '$995 – 1,600',
#               '2 Bedrooms': '$1,230 – 1,510',
#               '3 Bedrooms': 'NA',
#               'Latitude': '40.12211',
#               'Longitude': '-74.97351',
#               'URL': 'https://www.apartments.com/colonial-point-apartments-feasterville-trevose-pa/sd0qgc7/'},
#              8: {'property name': 'Henry on the Park Apartment Homes',
#               'property street': '7901 Henry Ave',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19128',
#               'Studio': 'Call for Rent',
#               '1 Bedroom': '$1,260 – 1,976',
#               '2 Bedrooms': '$1,375 – 2,373',
#               '3 Bedrooms': '$1,640 – 2,512',
#               'Latitude': '40.05648',
#               'Longitude': '-75.2316',
#               'URL': 'https://www.apartments.com/henry-on-the-park-apartment-homes-philadelphia-pa/8fjme23/'},
#              9: {'property name': '1200 Washington',
#               'property street': '1200 Washington Ave',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19147',
#               'Studio': '$1,375',
#               '1 Bedroom': '$1,652 – 1,727',
#               '2 Bedrooms': '$2,167',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.93716',
#               'Longitude': '-75.16334',
#               'URL': 'https://www.apartments.com/1200-washington-philadelphia-pa/3r6jt4d/'},
#              10: {'property name': 'The Girard',
#               'property street': '1199 Ludlow St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19107',
#               'Studio': 'NA',
#               '1 Bedroom': '$2,220 – 3,085',
#               '2 Bedrooms': '$3,285 – 4,675',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.95152',
#               'Longitude': '-75.15957',
#               'URL': 'https://www.apartments.com/the-girard-philadelphia-pa/xhslt9m/'},
#              11: {'property name': 'The Hub At 31 Brewerytown',
#               'property street': '1410 N 31st St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19121',
#               'Studio': '$1,324 – 1,440',
#               '1 Bedroom': '$1,492 – 1,814',
#               '2 Bedrooms': '$2,140 – 2,455',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.9784',
#               'Longitude': '-75.18627',
#               'URL': 'https://www.apartments.com/the-hub-at-31-brewerytown-philadelphia-pa/m3558gl/'},
#              12: {'property name': 'The Pointe',
#               'property street': '1415 N 31st St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19121',
#               'Studio': 'NA',
#               '1 Bedroom': '$1,569 – 1,794',
#               '2 Bedrooms': '$2,340',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.97851',
#               'Longitude': '-75.18551',
#               'URL': 'https://www.apartments.com/the-pointe-philadelphia-pa/f7p4zcs/'},
#              13: {'property name': '777 South Broad',
#               'property street': '777 S Broad St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19147',
#               'Studio': 'NA',
#               '1 Bedroom': 'Call for Rent',
#               '2 Bedrooms': '$2,466 – 13,099',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.94122',
#               'Longitude': '-75.16568',
#               'URL': 'https://www.apartments.com/777-south-broad-philadelphia-pa/vfpmd3f/'},
#              14: {'property name': 'Falls Village',
#               'property street': '2991 W School House Ln',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19144',
#               'Studio': 'NA',
#               '1 Bedroom': '$1,365 – 1,875',
#               '2 Bedrooms': '$1,425 – 1,950',
#               '3 Bedrooms': '$1,812 – 1,942',
#               'Latitude': '40.02528',
#               'Longitude': '-75.18656',
#               'URL': 'https://www.apartments.com/falls-village-philadelphia-pa/bpbz8k9/'},
#              15: {'property name': 'Lincoln Green',
#               'property street': '4000-4040 Presidential Blvd',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19131',
#               'Studio': 'NA',
#               '1 Bedroom': '$1,110 – 1,525',
#               '2 Bedrooms': '$1,610 – 1,725',
#               '3 Bedrooms': 'NA',
#               'Latitude': '40.00592',
#               'Longitude': '-75.21015',
#               'URL': 'https://www.apartments.com/lincoln-green-philadelphia-pa/wg5fjpl/'},
#              16: {'property name': 'The Point At Rittenhouse Row',
#               'property street': '1601 Sansom St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19103',
#               'Studio': 'NA',
#               '1 Bedroom': '$1,463 – 2,647',
#               '2 Bedrooms': '$2,266 – 2,996',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.95065',
#               'Longitude': '-75.16766',
#               'URL': 'https://www.apartments.com/the-point-at-rittenhouse-row-philadelphia-pa/575estn/'},
#              17: {'property name': 'The Ludlow',
#               'property street': '1101 Ludlow St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19107',
#               'Studio': '$1,695 – 2,000',
#               '1 Bedroom': '$1,500 – 2,825',
#               '2 Bedrooms': '$2,800 – 3,835',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.95149',
#               'Longitude': '-75.15866',
#               'URL': 'https://www.apartments.com/the-ludlow-philadelphia-pa/lpm616f/'},
#              18: {'property name': 'Enclaves',
#               'property street': '3900 Gateway Dr',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19145',
#               'Studio': 'NA',
#               '1 Bedroom': 'Call for Rent',
#               '2 Bedrooms': '$1,520 – 2,767',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.90108',
#               'Longitude': '-75.19251',
#               'URL': 'https://www.apartments.com/enclaves-philadelphia-pa/5yqhwcp/'},
#              19: {'property name': 'Versailles Apartments',
#               'property street': '1530 Locust St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19102',
#               'Studio': 'NA',
#               '1 Bedroom': '$2,295 – 2,875',
#               '2 Bedrooms': '$3,950 – 4,400',
#               '3 Bedrooms': '$6,995',
#               'Latitude': '39.94839',
#               'Longitude': '-75.16714',
#               'URL': 'https://www.apartments.com/versailles-apartments-philadelphia-pa/lj0d0yd/'},
#              20: {'property name': 'Tower Place',
#               'property street': '1400 Spring Garden St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19130',
#               'Studio': 'NA',
#               '1 Bedroom': '$1,686 – 2,045',
#               '2 Bedrooms': '$2,030 – 3,052',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.96201',
#               'Longitude': '-75.16225',
#               'URL': 'https://www.apartments.com/tower-place-philadelphia-pa/bex449c/'},
#              21: {'property name': 'Rushwood Apartments',
#               'property street': '10825 E Keswick Rd',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19154',
#               'Studio': 'NA',
#               '1 Bedroom': '$1,174 – 1,284',
#               '2 Bedrooms': '$1,264 – 1,445',
#               '3 Bedrooms': 'NA',
#               'Latitude': '40.08126',
#               'Longitude': '-74.98363',
#               'URL': 'https://www.apartments.com/rushwood-apartments-philadelphia-pa/g8qsrgz/'},
#              22: {'property name': 'The Piazza',
#               'property street': '1001 N 2nd St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19123',
#               'Studio': 'NA',
#               '1 Bedroom': '$1,805 – 2,095',
#               '2 Bedrooms': '$2,145 – 2,735',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.96673',
#               'Longitude': '-75.13992',
#               'URL': 'https://www.apartments.com/the-piazza-philadelphia-pa/pslb7ts/'},
#              23: {'property name': 'YONO',
#               'property street': '1320 W Somerville Ave',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19141',
#               'Studio': '$847 – 892',
#               '1 Bedroom': '$1,148',
#               '2 Bedrooms': 'NA',
#               '3 Bedrooms': 'NA',
#               'Latitude': '40.03459',
#               'Longitude': '-75.14417',
#               'URL': 'https://www.apartments.com/yono-philadelphia-pa/fzzev2t/'},
#              24: {'property name': 'The Franklin Residences',
#               'property street': '834 Chestnut St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19107',
#               'Studio': 'NA',
#               '1 Bedroom': '$1,799 – 2,400',
#               '2 Bedrooms': '$3,332 – 3,525',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.94939',
#               'Longitude': '-75.1552',
#               'URL': 'https://www.apartments.com/the-franklin-residences-philadelphia-pa/dbd8hml/'},
#              25: {'property name': 'Chestnut Hill Tower',
#               'property street': '7600 Stenton Ave',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19118',
#               'Studio': '$1,190 – 1,235',
#               '1 Bedroom': 'NA',
#               '2 Bedrooms': '$1,651 – 1,877',
#               '3 Bedrooms': 'NA',
#               'Latitude': '40.07325',
#               'Longitude': '-75.19056',
#               'URL': 'https://www.apartments.com/chestnut-hill-tower-philadelphia-pa/txhrqp9/'},
#              26: {'property name': 'Tacony Crossing by ONEWALL',
#               'property street': '155 E Godfrey Ave',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19120',
#               'Studio': 'NA',
#               '1 Bedroom': '$875 – 999',
#               '2 Bedrooms': '$1,100 – 1,300',
#               '3 Bedrooms': 'NA',
#               'Latitude': '40.04483',
#               'Longitude': '-75.11622',
#               'URL': 'https://www.apartments.com/tacony-crossing-by-onewall-philadelphia-pa/e1djx4m/'},
#              27: {'property name': 'Apex Manayunk',
#               'property street': '4601 Flat Rock Rd',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19127',
#               'Studio': 'NA',
#               '1 Bedroom': '$1,744 – 2,702',
#               '2 Bedrooms': '$2,144 – 3,742',
#               '3 Bedrooms': '$2,414 – 3,412',
#               'Latitude': '40.0291',
#               'Longitude': '-75.23162',
#               'URL': 'https://www.apartments.com/apex-manayunk-philadelphia-pa/eym0g5m/'},
#              28: {'property name': 'The Commonwealth',
#               'property street': '1201 Chestnut St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19107',
#               'Studio': 'NA',
#               '1 Bedroom': '$1,795 – 5,080',
#               '2 Bedrooms': '$2,595 – 5,525',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.95071',
#               'Longitude': '-75.16032',
#               'URL': 'https://www.apartments.com/the-commonwealth-philadelphia-pa/mcysbhk/'},
#              29: {'property name': 'Rittenhouse Hill',
#               'property street': '633 W Rittenhouse St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19144',
#               'Studio': '$1,125 – 1,245',
#               '1 Bedroom': '$1,465 – 1,695',
#               '2 Bedrooms': '$1,765 – 1,845',
#               '3 Bedrooms': 'NA',
#               'Latitude': '40.03108',
#               'Longitude': '-75.18618',
#               'URL': 'https://www.apartments.com/rittenhouse-hill-philadelphia-pa/zktw8dw/'},
#              30: {'property name': 'The Old Quaker Building',
#               'property street': '3514 Lancaster Ave',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19104',
#               'Studio': '$1,450 – 1,565',
#               '1 Bedroom': '$1,655 – 1,900',
#               '2 Bedrooms': '$2,280',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.95811',
#               'Longitude': '-75.19348',
#               'URL': 'https://www.apartments.com/the-old-quaker-building-philadelphia-pa/6syn5rv/'},
#              31: {'property name': 'Independence Lofts',
#               'property street': '525-533 N 11th St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19123',
#               'Studio': '$1,600 – 2,000',
#               '1 Bedroom': 'NA',
#               '2 Bedrooms': '$1,980 – 2,382',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.96244',
#               'Longitude': '-75.15551',
#               'URL': 'https://www.apartments.com/independence-lofts-philadelphia-pa/bxlql0b/'},
#              32: {'property name': 'The Point at City Line',
#               'property street': '6100 City Ave',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19131',
#               'Studio': 'NA',
#               '1 Bedroom': '$1,191 – 1,838',
#               '2 Bedrooms': '$1,532 – 1,874',
#               '3 Bedrooms': '$2,271 – 2,606',
#               'Latitude': '39.99048',
#               'Longitude': '-75.2486',
#               'URL': 'https://www.apartments.com/the-point-at-city-line-philadelphia-pa/nqv8lbn/'},
#              33: {'property name': 'Cherokee',
#               'property street': '7715 McCallum St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19118',
#               'Studio': 'NA',
#               '1 Bedroom': '$1,240',
#               '2 Bedrooms': '$1,460 – 1,820',
#               '3 Bedrooms': '$2,465',
#               'Latitude': '40.0576',
#               'Longitude': '-75.20961',
#               'URL': 'https://www.apartments.com/cherokee-philadelphia-pa/bh31d59/'},
#              34: {'property name': 'Imperial Towers',
#               'property street': '3801 Conshohocken Ave',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19131',
#               'Studio': '$1,090 – 1,410',
#               '1 Bedroom': '$1,070 – 1,725',
#               '2 Bedrooms': '$1,165 – 2,240',
#               '3 Bedrooms': 'NA',
#               'Latitude': '40.00377',
#               'Longitude': '-75.20576',
#               'URL': 'https://www.apartments.com/imperial-towers-philadelphia-pa/z5m8jhw/'},
#              35: {'property name': 'Bridge on Race',
#               'property street': '205 Race St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19106',
#               'Studio': '$1,625 – 2,305',
#               '1 Bedroom': '$1,850 – 3,000',
#               '2 Bedrooms': '$2,805 – 4,160',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.95398',
#               'Longitude': '-75.14331',
#               'URL': 'https://www.apartments.com/bridge-on-race-philadelphia-pa/xxf2e4n/'},
#              36: {'property name': 'The Avenue at East Falls',
#               'property street': '5450 Wissahickon Ave',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19144',
#               'Studio': '$738 – 1,158',
#               '1 Bedroom': '$981 – 1,468',
#               '2 Bedrooms': '$1,209 – 1,651',
#               '3 Bedrooms': 'NA',
#               'Latitude': '40.02515',
#               'Longitude': '-75.18168',
#               'URL': 'https://www.apartments.com/the-avenue-at-east-falls-philadelphia-pa/y48p92r/'},
#              37: {'property name': 'Lincoln Court Apartments',
#               'property street': '6351 Overbook Ave',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19151',
#               'Studio': 'NA',
#               '1 Bedroom': '$1,150 – 1,275',
#               '2 Bedrooms': '$1,400 – 1,500',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.98767',
#               'Longitude': '-75.25213',
#               'URL': 'https://www.apartments.com/lincoln-court-apartments-philadelphia-pa/wpls2mk/'},
#              38: {'property name': 'The Granary',
#               'property street': '1901 Callowhill St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19130',
#               'Studio': 'NA',
#               '1 Bedroom': '$1,581 – 3,045',
#               '2 Bedrooms': '$2,189 – 5,187',
#               '3 Bedrooms': '$6,007',
#               'Latitude': '39.96084',
#               'Longitude': '-75.17045',
#               'URL': 'https://www.apartments.com/the-granary-philadelphia-pa/w082d3k/'},
#              39: {'property name': '1919 Market St.',
#               'property street': '1919 Market St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19103',
#               'Studio': '$1,740 – 2,090',
#               '1 Bedroom': '$2,360 – 3,625',
#               '2 Bedrooms': '$2,915 – 5,095',
#               '3 Bedrooms': 'Call for Rent',
#               'Latitude': '39.95378',
#               'Longitude': '-75.17271',
#               'URL': 'https://www.apartments.com/1919-market-st-philadelphia-pa/z6xq6wz/'},
#              40: {'property name': 'Alden Park',
#               'property street': '5500 Wissahickon Ave',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19144',
#               'Studio': '$842 – 3,377',
#               '1 Bedroom': '$1,275 – 4,451',
#               '2 Bedrooms': '$1,294 – 11,392',
#               '3 Bedrooms': '$2,180 – 7,609',
#               'Latitude': '40.02708',
#               'Longitude': '-75.18425',
#               'URL': 'https://www.apartments.com/alden-park-philadelphia-pa/83f95m3/'},
#              41: {'property name': 'The Dane',
#               'property street': '2201 Bryn Mawr Ave',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19131',
#               'Studio': '$1,198 – 1,479',
#               '1 Bedroom': '$1,438 – 1,698',
#               '2 Bedrooms': '$1,595 – 2,211',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.99015',
#               'Longitude': '-75.22607',
#               'URL': 'https://www.apartments.com/the-dane-philadelphia-pa/mz3lvnk/'},
#              42: {'property name': 'Bala Apartments',
#               'property street': '4920-4950 City Ave',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19131',
#               'Studio': '$745',
#               '1 Bedroom': '$945 – 1,175',
#               '2 Bedrooms': '$1,175 – 1,225',
#               '3 Bedrooms': '$1,625',
#               'Latitude': '40.00016',
#               'Longitude': '-75.22772',
#               'URL': 'https://www.apartments.com/bala-apartments-philadelphia-pa/jejegh7/'},
#              43: {'property name': 'Lincoln Square',
#               'property street': '1000 S Broad St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19146',
#               'Studio': '$1,537 – 2,679',
#               '1 Bedroom': '$1,940 – 3,215',
#               '2 Bedrooms': '$2,692 – 4,142',
#               '3 Bedrooms': 'Call for Rent',
#               'Latitude': '39.93837',
#               'Longitude': '-75.16754',
#               'URL': 'https://www.apartments.com/lincoln-square-philadelphia-pa/2xrwhkb/'},
#              44: {'property name': 'Locust on the Park',
#               'property street': '201 S 25th St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19103',
#               'Studio': '$1,776 – 5,076',
#               '1 Bedroom': 'Call for Rent',
#               '2 Bedrooms': '$2,923 – 9,379',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.94975',
#               'Longitude': '-75.18053',
#               'URL': 'https://www.apartments.com/locust-on-the-park-philadelphia-pa/lrk4fcf/'},
#              45: {'property name': 'Park Towne Place Apartments',
#               'property street': '2200 Benjamin Franklin Pky',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19130',
#               'Studio': '$1,599 – 3,219',
#               '1 Bedroom': '$1,802 – 8,682',
#               '2 Bedrooms': '$2,210 – 27,498',
#               '3 Bedrooms': '$8,869 – 14,425',
#               'Latitude': '39.96055',
#               'Longitude': '-75.17773',
#               'URL': 'https://www.apartments.com/park-towne-place-apartments-philadelphia-pa/hczsx91/'},
#              46: {'property name': 'Dwell 2nd Street',
#               'property street': '1300 N 2nd St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19122',
#               'Studio': '$1,335 – 1,445',
#               '1 Bedroom': '$1,900 – 2,000',
#               '2 Bedrooms': '$2,360 – 2,605',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.97162',
#               'Longitude': '-75.13965',
#               'URL': 'https://www.apartments.com/dwell-2nd-street-philadelphia-pa/hg1zgw1/'},
#              47: {'property name': 'Arrive University City',
#               'property street': '3601 Market St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19104',
#               'Studio': '$1,685 – 2,675',
#               '1 Bedroom': '$1,840 – 2,649',
#               '2 Bedrooms': '$3,115 – 4,885',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.95663',
#               'Longitude': '-75.19446',
#               'URL': 'https://www.apartments.com/arrive-university-city-philadelphia-pa/yl2tbxt/'},
#              48: {'property name': '1600 Callowhill',
#               'property street': '1600 Callowhill St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19130',
#               'Studio': '$1,990',
#               '1 Bedroom': '$2,504',
#               '2 Bedrooms': 'Call for Rent',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.95981',
#               'Longitude': '-75.16576',
#               'URL': 'https://www.apartments.com/1600-callowhill-philadelphia-pa/smplw16/'},
#              49: {'property name': 'The Hamilton',
#               'property street': '1520 Hamilton St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19130',
#               'Studio': '$1,689 – 1,994',
#               '1 Bedroom': '$1,630 – 2,600',
#               '2 Bedrooms': '$2,235 – 3,287',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.96121',
#               'Longitude': '-75.16405',
#               'URL': 'https://www.apartments.com/the-hamilton-philadelphia-pa/jk2rxy5/'},
#              50: {'property name': 'The LVL 4125',
#               'property street': '4125-4136 Chestnut St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19104',
#               'Studio': 'Call for Rent',
#               '1 Bedroom': '$1,965 – 2,860',
#               '2 Bedrooms': 'Call for Rent',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.95626',
#               'Longitude': '-75.20552',
#               'URL': 'https://www.apartments.com/the-lvl-4125-philadelphia-pa/w67tywk/'},
#              51: {'property name': 'The National',
#               'property street': '121 N 2nd St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19106',
#               'Studio': '$1,991 – 2,066',
#               '1 Bedroom': '$2,148 – 2,293',
#               '2 Bedrooms': '$3,445 – 3,502',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.95233',
#               'Longitude': '-75.14281',
#               'URL': 'https://www.apartments.com/the-national-philadelphia-pa/jxddv96/'},
#              52: {'property name': 'Vue32',
#               'property street': '3201 Race St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19104',
#               'Studio': 'NA',
#               '1 Bedroom': '$1,970',
#               '2 Bedrooms': '$2,710 – 3,065',
#               '3 Bedrooms': '$5,100',
#               'Latitude': '39.95905',
#               'Longitude': '-75.18803',
#               'URL': 'https://www.apartments.com/vue32-philadelphia-pa/v60dc8g/'},
#              53: {'property name': '1213 Walnut',
#               'property street': '1213 Walnut St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19107',
#               'Studio': '$1,930 – 2,455',
#               '1 Bedroom': '$2,099 – 3,627',
#               '2 Bedrooms': '$2,951 – 4,066',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.94931',
#               'Longitude': '-75.16123',
#               'URL': 'https://www.apartments.com/1213-walnut-philadelphia-pa/851yr90/'},
#              54: {'property name': 'View at Old City',
#               'property street': '401 Race St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19106',
#               'Studio': '$1,552 – 2,042',
#               '1 Bedroom': '$1,926 – 3,101',
#               '2 Bedrooms': '$2,746 – 3,974',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.95459',
#               'Longitude': '-75.14716',
#               'URL': 'https://www.apartments.com/view-at-old-city-philadelphia-pa/x1bf4wq/'},
#              55: {'property name': 'The Pepper Building',
#               'property street': '1830 Lombard St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19146',
#               'Studio': 'NA',
#               '1 Bedroom': '$1,595 – 2,580',
#               '2 Bedrooms': '$2,150 – 3,075',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.94542',
#               'Longitude': '-75.17294',
#               'URL': 'https://www.apartments.com/the-pepper-building-philadelphia-pa/sr2b9f7/'},
#              56: {'property name': 'The Alexander',
#               'property street': '1601 Vine St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19102',
#               'Studio': '$1,704 – 3,861',
#               '1 Bedroom': '$2,112 – 4,632',
#               '2 Bedrooms': '$2,665 – 6,472',
#               '3 Bedrooms': '$4,476 – 9,415',
#               'Latitude': '39.95884',
#               'Longitude': '-75.16593',
#               'URL': 'https://www.apartments.com/the-alexander-philadelphia-pa/njfrbjm/'},
#              57: {'property name': 'Winchester Walk*',
#               'property street': '2600 Welsh Rd',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19152',
#               'Studio': 'NA',
#               '1 Bedroom': '$1,011 – 1,144',
#               '2 Bedrooms': '$1,204 – 1,299',
#               '3 Bedrooms': 'NA',
#               'Latitude': '40.07113',
#               'Longitude': '-75.03252',
#               'URL': 'https://www.apartments.com/winchester-walk-philadelphia-pa/c7hcw7g/'},
#              58: {'property name': 'The Collins',
#               'property street': '1125 Sansom St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19107',
#               'Studio': 'NA',
#               '1 Bedroom': '$1,871 – 2,864',
#               '2 Bedrooms': '$3,958 – 6,033',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.94991',
#               'Longitude': '-75.15945',
#               'URL': 'https://www.apartments.com/the-collins-philadelphia-pa/f79m92r/'},
#              59: {'property name': 'Goldtex',
#               'property street': '315 N 12th St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19107',
#               'Studio': '$1,665 – 1,775',
#               '1 Bedroom': '$1,895 – 2,605',
#               '2 Bedrooms': '$2,795 – 3,114',
#               '3 Bedrooms': 'Call for Rent',
#               'Latitude': '39.95818',
#               'Longitude': '-75.15814',
#               'URL': 'https://www.apartments.com/goldtex-philadelphia-pa/k40zgfc/'},
#              60: {'property name': 'International City Apartments',
#               'property street': '7900 Lindbergh Blvd',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19153',
#               'Studio': '$900 – 1,353',
#               '1 Bedroom': '$950 – 1,400',
#               '2 Bedrooms': '$1,135 – 1,550',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.90209',
#               'Longitude': '-75.24635',
#               'URL': 'https://www.apartments.com/international-city-apartments-philadelphia-pa/bwm4rj9/'},
#              61: {'property name': 'Crane Chinatown',
#               'property street': '1001 Vine St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19107',
#               'Studio': '$1,612 – 1,787',
#               '1 Bedroom': '$1,757 – 2,287',
#               '2 Bedrooms': '$2,847 – 2,997',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.95751',
#               'Longitude': '-75.15577',
#               'URL': 'https://www.apartments.com/crane-chinatown-philadelphia-pa/j07dm17/'},
#              62: {'property name': 'Ridge Carlton Apartments',
#               'property street': '7373 Ridge Ave',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19128',
#               'Studio': 'NA',
#               '1 Bedroom': '$989 – 1,199',
#               '2 Bedrooms': '$1,279 – 1,431',
#               '3 Bedrooms': 'NA',
#               'Latitude': '40.0478',
#               'Longitude': '-75.23402',
#               'URL': 'https://www.apartments.com/ridge-carlton-apartments-philadelphia-pa/9beej87/'},
#              63: {'property name': 'Adams at Presidential City',
#               'property street': '3800 City Ave',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19131',
#               'Studio': '$1,305 – 1,485',
#               '1 Bedroom': '$1,665 – 2,015',
#               '2 Bedrooms': '$1,925 – 2,235',
#               '3 Bedrooms': '$2,895 – 3,035',
#               'Latitude': '40.00826',
#               'Longitude': '-75.20561',
#               'URL': 'https://www.apartments.com/adams-at-presidential-city-philadelphia-pa/z2dgeqx/'},
#              64: {'property name': 'Jefferson at Presidential City',
#               'property street': '3900 City Ave',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19131',
#               'Studio': '$1,295 – 1,495',
#               '1 Bedroom': '$1,365 – 1,915',
#               '2 Bedrooms': '$2,395 – 2,775',
#               '3 Bedrooms': 'NA',
#               'Latitude': '40.00843',
#               'Longitude': '-75.2071',
#               'URL': 'https://www.apartments.com/jefferson-at-presidential-city-philadelphia-pa/90t98h5/'},
#              65: {'property name': 'Washington at Presidential City',
#               'property street': '3902 City Ave',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19131',
#               'Studio': '$1,345 – 1,525',
#               '1 Bedroom': '$1,475 – 1,885',
#               '2 Bedrooms': '$2,015 – 2,085',
#               '3 Bedrooms': 'NA',
#               'Latitude': '40.00794',
#               'Longitude': '-75.2084',
#               'URL': 'https://www.apartments.com/washington-at-presidential-city-philadelphia-pa/g969jkx/'},
#              66: {'property name': 'The Atlantic',
#               'property street': '1401 Spruce St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19102',
#               'Studio': '$2,165 – 2,315',
#               '1 Bedroom': '$2,295 – 6,395',
#               '2 Bedrooms': '$3,655 – 6,145',
#               '3 Bedrooms': '$6,005 – 7,845',
#               'Latitude': '39.9473',
#               'Longitude': '-75.16508',
#               'URL': 'https://www.apartments.com/the-atlantic-philadelphia-pa/hqf41b0/'},
#              67: {'property name': 'Penthouses at Presidential City',
#               'property street': '76 Winding Dr',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19131',
#               'Studio': 'NA',
#               '1 Bedroom': '$2,715 – 2,935',
#               '2 Bedrooms': '$3,095 – 3,325',
#               '3 Bedrooms': '$4,535 – 4,735',
#               'Latitude': '40.00822',
#               'Longitude': '-75.20566',
#               'URL': 'https://www.apartments.com/penthouses-at-presidential-city-philadelphia-pa/79brkfz/'},
#              68: {'property name': 'Canterbury Court Apartment Homes',
#               'property street': '9951 Academy Rd',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19114',
#               'Studio': 'NA',
#               '1 Bedroom': '$1,010 – 1,175',
#               '2 Bedrooms': 'NA',
#               '3 Bedrooms': 'NA',
#               'Latitude': '40.07619',
#               'Longitude': '-75.0001',
#               'URL': 'https://www.apartments.com/canterbury-court-apartment-homes-philadelphia-pa/1n3t3j6/'},
#              69: {'property name': 'Madison at Presidential City',
#               'property street': '3800-3900 City Ave',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19131',
#               'Studio': '$1,315 – 1,735',
#               '1 Bedroom': '$1,480 – 1,915',
#               '2 Bedrooms': '$1,935 – 2,505',
#               '3 Bedrooms': '$2,755 – 3,005',
#               'Latitude': '40.00822',
#               'Longitude': '-75.20968',
#               'URL': 'https://www.apartments.com/madison-at-presidential-city-philadelphia-pa/ry3jv13/'},
#              70: {'property name': 'Lyndon At The Curtis',
#               'property street': '601 Walnut St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19106',
#               'Studio': '$2,800',
#               '1 Bedroom': '$2,875 – 4,700',
#               '2 Bedrooms': 'NA',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.94788',
#               'Longitude': '-75.15137',
#               'URL': 'https://www.apartments.com/lyndon-at-the-curtis-philadelphia-pa/pw2ccrr/'},
#              71: {'property name': 'Germantown Square',
#               'property street': '45-47 West Haines St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19144',
#               'Studio': 'NA',
#               '1 Bedroom': '$1,300 – 1,500',
#               '2 Bedrooms': '$1,750 – 1,900',
#               '3 Bedrooms': 'NA',
#               'Latitude': '40.03787',
#               'Longitude': '-75.17781',
#               'URL': 'https://www.apartments.com/germantown-square-philadelphia-pa/jyqqn67/'},
#              72: {'property name': 'SDG Residences of Fairmount',
#               'property street': '745 N 20th St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19130',
#               'Studio': 'NA',
#               '1 Bedroom': '$1,550 – 1,850',
#               '2 Bedrooms': '$1,900 – 2,500',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.96829',
#               'Longitude': '-75.16249',
#               'URL': 'https://www.apartments.com/sdg-residences-of-fairmount-philadelphia-pa/bbz6jk8/'},
#              73: {'property name': 'Hamilton Court',
#               'property street': '3816-3836 S Chestnut St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19104',
#               'Studio': 'NA',
#               '1 Bedroom': '$1,945 – 1,995',
#               '2 Bedrooms': '$2,845 – 3,095',
#               '3 Bedrooms': '$3,500 – 3,795',
#               'Latitude': '39.95481',
#               'Longitude': '-75.19932',
#               'URL': 'https://www.apartments.com/hamilton-court-philadelphia-pa/0pj5gy2/'},
#              74: {'property name': 'Palazzo at The Piazza',
#               'property street': '1050 N Hancock St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19123',
#               'Studio': 'NA',
#               '1 Bedroom': '$2,150 – 2,945',
#               '2 Bedrooms': '$2,900 – 3,100',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.96675',
#               'Longitude': '-75.1392',
#               'URL': 'https://www.apartments.com/palazzo-at-the-piazza-philadelphia-pa/2szmfl9/'},
#              75: {'property name': 'West River Apartments',
#               'property street': '3601 Conshohocken Ave',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19131',
#               'Studio': 'NA',
#               '1 Bedroom': '$1,395 – 1,425',
#               '2 Bedrooms': '$1,625 – 1,710',
#               '3 Bedrooms': 'NA',
#               'Latitude': '40.00424',
#               'Longitude': '-75.20324',
#               'URL': 'https://www.apartments.com/west-river-apartments-philadelphia-pa/7c47vez/'},
#              76: {'property name': 'Liberty Square',
#               'property street': '1203 Germantown Ave',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19122',
#               'Studio': 'NA',
#               '1 Bedroom': '$1,875 – 2,475',
#               '2 Bedrooms': '$2,450 – 2,995',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.97083',
#               'Longitude': '-75.14053',
#               'URL': 'https://www.apartments.com/liberty-square-philadelphia-pa/hy0hmv0/'},
#              77: {'property name': 'The Civic',
#               'property street': '1600-1650 W Girard Ave',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19130',
#               'Studio': '$1,329 – 1,850',
#               '1 Bedroom': '$1,750 – 2,150',
#               '2 Bedrooms': '$2,292 – 2,521',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.97151',
#               'Longitude': '-75.16314',
#               'URL': 'https://www.apartments.com/the-civic-philadelphia-pa/16cseb4/'},
#              78: {'property name': 'Diamond Green-Student Housing!!',
#               'property street': '1000 Diamond St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19122',
#               'Studio': 'NA',
#               '1 Bedroom': 'NA',
#               '2 Bedrooms': 'NA',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.98361',
#               'Longitude': '-75.15002',
#               'URL': 'https://www.apartments.com/diamond-green-student-housing-philadelphia-pa/rx12fs2/'},
#              79: {'property name': 'The Station at Manayunk',
#               'property street': '1 Parker Ave',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19128',
#               'Studio': 'NA',
#               '1 Bedroom': '$1,470 – 1,520',
#               '2 Bedrooms': '$1,964 – 1,994',
#               '3 Bedrooms': 'NA',
#               'Latitude': '40.03425',
#               'Longitude': '-75.23627',
#               'URL': 'https://www.apartments.com/the-station-at-manayunk-philadelphia-pa/ncwv55n/'},
#              80: {'property name': 'The View at Manayunk Apartments',
#               'property street': '4136-40 Mitchell St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19128',
#               'Studio': '$1,295',
#               '1 Bedroom': '$1,395 – 1,795',
#               '2 Bedrooms': '$1,495 – 2,125',
#               '3 Bedrooms': 'NA',
#               'Latitude': '40.0269',
#               'Longitude': '-75.21192',
#               'URL': 'https://www.apartments.com/the-view-at-manayunk-apartments-philadelphia-pa/rd3g7l0/'},
#              81: {'property name': 'Dobson Studios, Lofts and apartments',
#               'property street': '4055 Ridge Ave',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19129',
#               'Studio': '$945 – 1,055',
#               '1 Bedroom': '$1,030 – 1,780',
#               '2 Bedrooms': '$1,430 – 1,980',
#               '3 Bedrooms': '$2,385 – 2,435',
#               'Latitude': '40.00775',
#               'Longitude': '-75.18894',
#               'URL': 'https://www.apartments.com/dobson-studios-lofts-and-apartments-philadelphia-pa/z18pmxz/'},
#              82: {'property name': 'The Porter',
#               'property street': '2940 W Thompson St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19121',
#               'Studio': '$1,250',
#               '1 Bedroom': '$1,400 – 1,700',
#               '2 Bedrooms': 'NA',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.9764',
#               'Longitude': '-75.18453',
#               'URL': 'https://www.apartments.com/the-porter-philadelphia-pa/kyf9blc/'},
#              83: {'property name': 'Stable Lofts',
#               'property street': '631 N Broad St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19123',
#               'Studio': '$1,750',
#               '1 Bedroom': '$1,900 – 2,500',
#               '2 Bedrooms': '$2,800 – 3,600',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.9645',
#               'Longitude': '-75.16052',
#               'URL': 'https://www.apartments.com/stable-lofts-philadelphia-pa/tzp3cnc/'},
#              84: {'property name': 'Edgewater Apartments',
#               'property street': '2323 Race St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19103',
#               'Studio': '$1,890 – 1,975',
#               '1 Bedroom': '$2,400 – 2,555',
# ...
#               'Longitude': '-75.12083',
#               'URL': 'https://www.apartments.com/1931-e-somerset-st-philadelphia-pa/jl46l95/'},
#              748: {'property name': '6700-6702 Keystone St Unit 1ST FL',
#               'property street': '6700-6702 Keystone St Unit 1ST FL',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19135',
#               'Studio': 'NA',
#               '1 Bedroom': 'NA',
#               '2 Bedrooms': '$900',
#               '3 Bedrooms': 'NA',
#               'Latitude': '40.02185',
#               'Longitude': '-75.04426',
#               'URL': 'https://www.apartments.com/6700-6702-keystone-st-philadelphia-pa-unit-1st-fl/bk07bwc/'},
#              749: {'property name': 'Palazzo at The Piazza',
#               'property street': '1050 N Hancock St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19123',
#               'Studio': 'NA',
#               '1 Bedroom': '$2,150 – 2,945',
#               '2 Bedrooms': '$2,900 – 3,100',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.96675',
#               'Longitude': '-75.1392',
#               'URL': 'https://www.apartments.com/palazzo-at-the-piazza-philadelphia-pa/2szmfl9/'},
#              750: {'property name': '311 E Girard Ave',
#               'property street': '311 E Girard Ave',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19125',
#               'Studio': 'NA',
#               '1 Bedroom': 'NA',
#               '2 Bedrooms': 'NA',
#               '3 Bedrooms': '$2,500',
#               'Latitude': '39.97008',
#               'Longitude': '-75.13153',
#               'URL': 'https://www.apartments.com/311-e-girard-ave-philadelphia-pa/ldkplnd/'},
#              751: {'property name': '2711 Eddington St',
#               'property street': '2711 Eddington St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19137',
#               'Studio': 'NA',
#               '1 Bedroom': 'NA',
#               '2 Bedrooms': 'NA',
#               '3 Bedrooms': '$1,400',
#               'Latitude': '39.99665',
#               'Longitude': '-75.07795',
#               'URL': 'https://www.apartments.com/2711-eddington-st-philadelphia-pa/rb1zep0/'},
#              752: {'property name': '705 N Dekalb St',
#               'property street': '705 N Dekalb St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19104',
#               'Studio': 'NA',
#               '1 Bedroom': 'NA',
#               '2 Bedrooms': 'NA',
#               '3 Bedrooms': '$1,295',
#               'Latitude': '39.96621',
#               'Longitude': '-75.197',
#               'URL': 'https://www.apartments.com/705-n-dekalb-st-philadelphia-pa/439jwrh/'},
#              753: {'property name': '3118 N 16th St',
#               'property street': '3118 N 16th St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19132',
#               'Studio': 'NA',
#               '1 Bedroom': 'NA',
#               '2 Bedrooms': 'NA',
#               '3 Bedrooms': 'NA',
#               'Latitude': '40.00093',
#               'Longitude': '-75.15657',
#               'URL': 'https://www.apartments.com/3118-n-16th-st-philadelphia-pa/87tdkx2/'},
#              754: {'property name': '1611 N 33rd St Unit F1',
#               'property street': '1611 N 33rd St Unit F1',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19121',
#               'Studio': 'NA',
#               '1 Bedroom': 'NA',
#               '2 Bedrooms': '$925',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.98152',
#               'Longitude': '-75.18824',
#               'URL': 'https://www.apartments.com/1611-n-33rd-st-philadelphia-pa-unit-f1/864vys1/'},
#              755: {'property name': 'West River Apartments',
#               'property street': '3601 Conshohocken Ave',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19131',
#               'Studio': 'NA',
#               '1 Bedroom': '$1,395 – 1,425',
#               '2 Bedrooms': '$1,625 – 1,710',
#               '3 Bedrooms': 'NA',
#               'Latitude': '40.00424',
#               'Longitude': '-75.20324',
#               'URL': 'https://www.apartments.com/west-river-apartments-philadelphia-pa/7c47vez/'},
#              756: {'property name': '2525 Ashford St',
#               'property street': '2525 Ashford St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19153',
#               'Studio': 'NA',
#               '1 Bedroom': 'NA',
#               '2 Bedrooms': 'NA',
#               '3 Bedrooms': '$1,500',
#               'Latitude': '39.91156',
#               'Longitude': '-75.24413',
#               'URL': 'https://www.apartments.com/2525-ashford-st-philadelphia-pa/z8pf2xy/'},
#              757: {'property name': '2841 S Randolph St',
#               'property street': '2841 S Randolph St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19148',
#               'Studio': 'NA',
#               '1 Bedroom': 'NA',
#               '2 Bedrooms': 'NA',
#               '3 Bedrooms': '$1,400',
#               'Latitude': '39.91288',
#               'Longitude': '-75.1578',
#               'URL': 'https://www.apartments.com/2841-s-randolph-st-philadelphia-pa/fl1e5br/'},
#              758: {'property name': 'Liberty Square',
#               'property street': '1203 Germantown Ave',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19122',
#               'Studio': 'NA',
#               '1 Bedroom': '$1,875 – 2,475',
#               '2 Bedrooms': '$2,450 – 2,995',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.97083',
#               'Longitude': '-75.14053',
#               'URL': 'https://www.apartments.com/liberty-square-philadelphia-pa/hy0hmv0/'},
#              759: {'property name': 'The Civic',
#               'property street': '1600-1650 W Girard Ave',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19130',
#               'Studio': '$1,329 – 1,850',
#               '1 Bedroom': '$1,750 – 2,150',
#               '2 Bedrooms': '$2,292 – 2,521',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.97151',
#               'Longitude': '-75.16314',
#               'URL': 'https://www.apartments.com/the-civic-philadelphia-pa/16cseb4/'},
#              760: {'property name': 'Diamond Green-Student Housing!!',
#               'property street': '1000 Diamond St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19122',
#               'Studio': 'NA',
#               '1 Bedroom': 'NA',
#               '2 Bedrooms': 'NA',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.98361',
#               'Longitude': '-75.15002',
#               'URL': 'https://www.apartments.com/diamond-green-student-housing-philadelphia-pa/rx12fs2/'},
#              761: {'property name': 'The Station at Manayunk',
#               'property street': '1 Parker Ave',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19128',
#               'Studio': 'NA',
#               '1 Bedroom': '$1,470 – 1,520',
#               '2 Bedrooms': '$1,964 – 1,994',
#               '3 Bedrooms': 'NA',
#               'Latitude': '40.03425',
#               'Longitude': '-75.23627',
#               'URL': 'https://www.apartments.com/the-station-at-manayunk-philadelphia-pa/ncwv55n/'},
#              762: {'property name': 'The View at Manayunk Apartments',
#               'property street': '4136-40 Mitchell St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19128',
#               'Studio': '$1,295',
#               '1 Bedroom': '$1,395 – 1,795',
#               '2 Bedrooms': '$1,495 – 2,125',
#               '3 Bedrooms': 'NA',
#               'Latitude': '40.0269',
#               'Longitude': '-75.21192',
#               'URL': 'https://www.apartments.com/the-view-at-manayunk-apartments-philadelphia-pa/rd3g7l0/'},
#              763: {'property name': 'Dobson Studios, Lofts and apartments',
#               'property street': '4055 Ridge Ave',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19129',
#               'Studio': '$945 – 1,055',
#               '1 Bedroom': '$1,030 – 1,780',
#               '2 Bedrooms': '$1,430 – 1,980',
#               '3 Bedrooms': '$2,385 – 2,435',
#               'Latitude': '40.00775',
#               'Longitude': '-75.18894',
#               'URL': 'https://www.apartments.com/dobson-studios-lofts-and-apartments-philadelphia-pa/z18pmxz/'},
#              764: {'property name': 'The Porter',
#               'property street': '2940 W Thompson St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19121',
#               'Studio': '$1,250',
#               '1 Bedroom': '$1,400 – 1,700',
#               '2 Bedrooms': 'NA',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.9764',
#               'Longitude': '-75.18453',
#               'URL': 'https://www.apartments.com/the-porter-philadelphia-pa/kyf9blc/'},
#              765: {'property name': 'Stable Lofts',
#               'property street': '631 N Broad St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19123',
#               'Studio': '$1,750',
#               '1 Bedroom': '$1,900 – 2,500',
#               '2 Bedrooms': '$2,800 – 3,600',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.9645',
#               'Longitude': '-75.16052',
#               'URL': 'https://www.apartments.com/stable-lofts-philadelphia-pa/tzp3cnc/'},
#              766: {'property name': 'The Wellington',
#               'property street': '135 S 19th St',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19103',
#               'Studio': '$1,295',
#               '1 Bedroom': '$1,695 – 2,300',
#               '2 Bedrooms': '$2,750 – 3,200',
#               '3 Bedrooms': '$7,500',
#               'Latitude': '39.95074',
#               'Longitude': '-75.17221',
#               'URL': 'https://www.apartments.com/the-wellington-philadelphia-pa/h4qd3v1/'},
#              767: {'property name': 'Northbrook Apartment Homes',
#               'property street': '1340 Stewarts Way',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19154',
#               'Studio': 'NA',
#               '1 Bedroom': '$989 – 1,049',
#               '2 Bedrooms': '$1,169 – 1,219',
#               '3 Bedrooms': 'NA',
#               'Latitude': '40.09686',
#               'Longitude': '-74.98482',
#               'URL': 'https://www.apartments.com/northbrook-apartment-homes-philadelphia-pa/9mcjb25/'},
#              768: {'property name': 'The Mansion at Bala',
#               'property street': '4700 City Ave',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19131',
#               'Studio': 'NA',
#               '1 Bedroom': '$1,345 – 1,815',
#               '2 Bedrooms': '$1,825 – 2,070',
#               '3 Bedrooms': '$2,885',
#               'Latitude': '40.00113',
#               'Longitude': '-75.2252',
#               'URL': 'https://www.apartments.com/the-mansion-at-bala-philadelphia-pa/48hrl8l/'},
#              769: {'property name': 'Lennox Apartments',
#               'property street': '236 W Walnut Ln',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19144',
#               'Studio': '$715 – 755',
#               '1 Bedroom': '$825 – 895',
#               '2 Bedrooms': 'NA',
#               '3 Bedrooms': 'NA',
#               'Latitude': '40.03645',
#               'Longitude': '-75.18273',
#               'URL': 'https://www.apartments.com/lennox-apartments-philadelphia-pa/bm4swb8/'},
#              770: {'property name': 'The Legacy at Drexel Arms',
#               'property street': '6301 Overbrook Ave',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19151',
#               'Studio': 'NA',
#               '1 Bedroom': 'NA',
#               '2 Bedrooms': 'NA',
#               '3 Bedrooms': 'NA',
#               'Latitude': '39.98849',
#               'Longitude': '-75.2504',
#               'URL': 'https://www.apartments.com/the-legacy-at-drexel-arms-philadelphia-pa/lgelnpg/'},
#              771: {'property name': 'The Lofts At Chimney Hill',
#               'property street': '161 Leverington Ave',
#               'property city': 'Philadelphia',
#               'property state': 'PA',
#               'property zipcode': '19127',
#               'Studio': 'NA',
#               '1 Bedroom': '$1,300 – 1,700',
#               '2 Bedrooms': '$1,550 – 1,800',
#               '3 Bedrooms': 'NA',
#               'Latitude': '40.02987',
#               'Longitude': '-75.22745',
#               'URL': 'https://www.apartments.com/the-lofts-at-chimney-hill-philadelphia-pa/cmjwghg/'},
#              772: {'property name': 'Salem Harbour',
#               'property street': '455 Old Bridge Rd',
#               'property city': 'Bensalem',
#               'property state': 'PA',
#               'property zipcode': '19020',
#               'Studio': 'NA',
#               '1 Bedroom': '$1,291 – 1,426',
#               '2 Bedrooms': '$1,538 – 1,638',
#               '3 Bedrooms': 'NA',
#               'Latitude': '40.05504',
#               'Longitude': '-74.98002',
#               'URL': 'https://www.apartments.com/salem-harbour-bensalem-pa/h5q6mh3/'},
#              773: {'property name': 'The Kelly',
#               'property street': '10 Union Ave',
#               'property city': 'Bala Cynwyd',
#               'property state': 'PA',
#               'property zipcode': '19004',
#               'Studio': 'NA',
#               '1 Bedroom': '$1,700 – 2,147',
#               '2 Bedrooms': '$2,550 – 3,620',
#               '3 Bedrooms': '$3,705 – 3,970',
#               'Latitude': '40.00317',
#               'Longitude': '-75.22993',
#               'URL': 'https://www.apartments.com/the-kelly-bala-cynwyd-pa/hezp011/'},
#              774: {'property name': 'Hamilton Court East Apartments',
#               'property street': '3455 Street Road',
#               'property city': 'Bensalem',
#               'property state': 'PA',
#               'property zipcode': '19020',
#               'Studio': 'NA',
#               '1 Bedroom': '$999 – 1,149',
#               '2 Bedrooms': '$1,349',
#               '3 Bedrooms': 'NA',
#               'Latitude': '40.12427',
#               'Longitude': '-74.96165',
#               'URL': 'https://www.apartments.com/hamilton-court-east-apartments-bensalem-pa/1r0mh55/'},
#              775: {'property name': 'Towers at Wyncote',
#               'property street': '8440 Limekiln Pike',
#               'property city': 'Wyncote',
#               'property state': 'PA',
#               'property zipcode': '19095',
#               'Studio': '$1,095 – 1,843',
#               '1 Bedroom': '$1,270 – 2,530',
#               '2 Bedrooms': '$1,400 – 4,169',
#               '3 Bedrooms': '$2,160 – 4,191',
#               'Latitude': '40.085',
#               'Longitude': '-75.16492',
#               'URL': 'https://www.apartments.com/towers-at-wyncote-wyncote-pa/dk1pfrl/'}})

# %%
#storing the data in CSV file using pandas.

df = pandas.DataFrame(property_details).T
neworder = ['property name', 'property street','property city','property state','property zipcode','Studio', '1 Bedroom', 
            '2 Bedrooms', '3 Bedrooms', 'Latitude', 'Longitude', 'URL' ]
df=df.reindex(columns=neworder)
df.to_csv("data/rental_data_set.csv", encoding = 'utf-8-sig')

# %%
df.head(5)
# Out:
#                          property name     property street property city  \
# 1                Chestnut Hill Village  7715 Crittenden St  Philadelphia
# 2                  Hanover North Broad  322-344 N Broad St  Philadelphia
# 3                    Fallsview Gardens     3026 W Queen Ln  Philadelphia
# 4                           The Irvine       780 S 52nd St  Philadelphia
# 5  Brookview Apartments at Elkins Park   1235 Ashbourne Rd   Elkins Park
#
#   property state property zipcode          Studio       1 Bedroom  \
# 1             PA            19118              NA  $1,227 – 1,699
# 2             PA            19102  $1,582 – 2,005  $1,701 – 2,742
# 3             PA            19129              NA              NA
# 4             PA            19143  $1,295 – 1,645  $1,575 – 1,795
# 5             PA            19027              NA  $1,215 – 1,525
#
#        2 Bedrooms      3 Bedrooms  Latitude  Longitude  \
# 1  $1,629 – 2,368  $2,039 – 2,054  40.07447  -75.19484
# 2  $2,360 – 3,952  $3,781 – 3,816  39.95934  -75.16261
# 3  $1,250 – 1,550              NA  40.01916  -75.18168
# 4  $2,095 – 2,345  $2,565 – 2,645  39.94624  -75.22589
# 5  $1,600 – 1,765  $1,940 – 2,095  40.06646  -75.11785
#
#                                                  URL
# 1  https://www.apartments.com/chestnut-hill-villa...
# 2  https://www.apartments.com/hanover-north-broad...
# 3  https://www.apartments.com/fallsview-gardens-p...
# 4  https://www.apartments.com/the-irvine-philadel...
# 5  https://www.apartments.com/brookview-apartment...
